# %%
import torch
import os
import torchaudio
from transformers import Wav2Vec2ForSequenceClassification, Wav2Vec2FeatureExtractor

# %%
audio_path = '/home/cslab03/Documents/ASRColab/ASRColab/wav_separate_sounds_mono/'

# %%
train_splits = ['ov1s1_wav', 'ov1s2_wav']
val_split = 'ov1s3_wav'

X_train = []
X_val = []
X_test = []

for split in train_splits:
  for file_ in os.listdir(audio_path+split):
      if 'tra' in file_:
          X_train.append(file_)
      elif 'tst' in file_:
          X_test.append(file_)

for file_ in os.listdir(audio_path+val_split):
    if 'tra' in file_:
        X_val.append(file_)
    elif 'tst' in file_:
        X_test.append(file_)

# %%
print(len(X_train), len(X_val), len(X_test))
# Out:
# 2987 1654 1033

# %%
X_train
# Out:
# ['tra_075_5_ov1_s1_00.wav',
#  'tra_238_8_ov1_s1_04.wav',
#  'tra_177_12_ov1_s1_09.wav',
#  'tra_085_8_ov1_s1_09.wav',
#  'tra_228_5_ov1_s1_04.wav',
#  'tra_049_12_ov1_s1_00.wav',
#  'tra_196_5_ov1_s1_03.wav',
#  'tra_195_0_ov1_s1_09.wav',
#  'tra_215_8_ov1_s1_02.wav',
#  'tra_139_3_ov1_s1_01.wav',
#  'tra_061_7_ov1_s1_04.wav',
#  'tra_090_10_ov1_s1_03.wav',
#  'tra_154_1_ov1_s1_02.wav',
#  'tra_029_14_ov1_s1_09.wav',
#  'tra_095_10_ov1_s1_01.wav',
#  'tra_099_13_ov1_s1_03.wav',
#  'tra_051_9_ov1_s1_09.wav',
#  'tra_108_8_ov1_s1_02.wav',
#  'tra_156_13_ov1_s1_04.wav',
#  'tra_104_0_ov1_s1_07.wav',
#  'tra_196_10_ov1_s1_04.wav',
#  'tra_076_2_ov1_s1_08.wav',
#  'tra_101_4_ov1_s1_07.wav',
#  'tra_006_5_ov1_s1_04.wav',
#  'tra_157_3_ov1_s1_08.wav',
#  'tra_140_15_ov1_s1_08.wav',
#  'tra_154_2_ov1_s1_09.wav',
#  'tra_159_5_ov1_s1_00.wav',
#  'tra_156_8_ov1_s1_08.wav',
#  'tra_146_7_ov1_s1_06.wav',
#  'tra_132_4_ov1_s1_01.wav',
#  'tra_071_6_ov1_s1_00.wav',
#  'tra_010_3_ov1_s1_05.wav',
#  'tra_137_10_ov1_s1_04.wav',
#  'tra_213_0_ov1_s1_07.wav',
#  'tra_198_10_ov1_s1_06.wav',
#  'tra_171_6_ov1_s1_02.wav',
#  'tra_033_10_ov1_s1_10.wav',
#  'tra_005_8_ov1_s1_07.wav',
#  'tra_228_9_ov1_s1_03.wav',
#  'tra_002_3_ov1_s1_00.wav',
#  'tra_196_13_ov1_s1_06.wav',
#  'tra_141_5_ov1_s1_09.wav',
#  'tra_102_9_ov1_s1_01.wav',
#  'tra_141_7_ov1_s1_01.wav',
#  'tra_004_8_ov1_s1_00.wav',
#  'tra_000_10_ov1_s1_02.wav',
#  'tra_224_0_ov1_s1_02.wav',
#  'tra_101_3_ov1_s1_09.wav',
#  'tra_228_13_ov1_s1_02.wav',
#  'tra_025_10_ov1_s1_00.wav',
#  'tra_202_10_ov1_s1_08.wav',
#  'tra_040_14_ov1_s1_06.wav',
#  'tra_161_13_ov1_s1_09.wav',
#  'tra_185_14_ov1_s1_06.wav',
#  'tra_208_12_ov1_s1_08.wav',
#  'tra_045_12_ov1_s1_04.wav',
#  'tra_028_6_ov1_s1_07.wav',
#  'tra_075_7_ov1_s1_07.wav',
#  'tra_031_4_ov1_s1_09.wav',
#  'tra_199_7_ov1_s1_02.wav',
#  'tra_054_8_ov1_s1_04.wav',
#  'tra_157_4_ov1_s1_03.wav',
#  'tra_176_5_ov1_s1_03.wav',
#  'tra_010_9_ov1_s1_05.wav',
#  'tra_081_4_ov1_s1_09.wav',
#  'tra_114_0_ov1_s1_02.wav',
#  'tra_135_2_ov1_s1_04.wav',
#  'tra_048_2_ov1_s1_02.wav',
#  'tra_185_1_ov1_s1_02.wav',
#  'tra_172_13_ov1_s1_06.wav',
#  'tra_024_3_ov1_s1_01.wav',
#  'tra_125_12_ov1_s1_04.wav',
#  'tra_079_8_ov1_s1_08.wav',
#  'tra_187_13_ov1_s1_00.wav',
#  'tra_075_1_ov1_s1_03.wav',
#  'tra_098_7_ov1_s1_04.wav',
#  'tra_099_3_ov1_s1_05.wav',
#  'tra_108_9_ov1_s1_05.wav',
#  'tra_029_15_ov1_s1_09.wav',
#  'tra_028_8_ov1_s1_06.wav',
#  'tra_071_0_ov1_s1_07.wav',
#  'tra_063_14_ov1_s1_10.wav',
#  'tra_143_5_ov1_s1_09.wav',
#  'tra_199_10_ov1_s1_03.wav',
#  'tra_172_5_ov1_s1_06.wav',
#  'tra_045_11_ov1_s1_04.wav',
#  'tra_117_3_ov1_s1_10.wav',
#  'tra_168_0_ov1_s1_08.wav',
#  'tra_009_10_ov1_s1_01.wav',
#  'tra_140_11_ov1_s1_02.wav',
#  'tra_090_5_ov1_s1_07.wav',
#  'tra_198_8_ov1_s1_04.wav',
#  'tra_071_3_ov1_s1_04.wav',
#  'tra_004_4_ov1_s1_10.wav',
#  'tra_067_0_ov1_s1_03.wav',
#  'tra_005_6_ov1_s1_01.wav',
#  'tra_231_6_ov1_s1_08.wav',
#  'tra_091_3_ov1_s1_05.wav',
#  'tra_146_10_ov1_s1_03.wav',
#  'tra_097_13_ov1_s1_06.wav',
#  'tra_024_9_ov1_s1_04.wav',
#  'tra_079_15_ov1_s1_05.wav',
#  'tra_125_7_ov1_s1_02.wav',
#  'tra_172_6_ov1_s1_05.wav',
#  'tra_017_0_ov1_s1_08.wav',
#  'tra_172_12_ov1_s1_04.wav',
#  'tra_189_3_ov1_s1_06.wav',
#  'tra_163_7_ov1_s1_08.wav',
#  'tra_203_4_ov1_s1_01.wav',
#  'tra_168_5_ov1_s1_09.wav',
#  'tra_167_15_ov1_s1_05.wav',
#  'tra_228_15_ov1_s1_04.wav',
#  'tra_239_8_ov1_s1_05.wav',
#  'tra_132_5_ov1_s1_10.wav',
#  'tra_224_8_ov1_s1_06.wav',
#  'tra_181_6_ov1_s1_07.wav',
#  'tra_000_9_ov1_s1_05.wav',
#  'tra_040_12_ov1_s1_09.wav',
#  'tra_132_11_ov1_s1_04.wav',
#  'tra_181_4_ov1_s1_07.wav',
#  'tra_028_4_ov1_s1_03.wav',
#  'tra_230_6_ov1_s1_04.wav',
#  'tra_102_6_ov1_s1_01.wav',
#  'tra_049_0_ov1_s1_04.wav',
#  'tra_185_2_ov1_s1_03.wav',
#  'tra_029_9_ov1_s1_07.wav',
#  'tra_125_10_ov1_s1_04.wav',
#  'tra_199_11_ov1_s1_05.wav',
#  'tra_079_5_ov1_s1_07.wav',
#  'tra_231_2_ov1_s1_04.wav',
#  'tra_049_1_ov1_s1_03.wav',
#  'tra_108_3_ov1_s1_08.wav',
#  'tra_202_7_ov1_s1_09.wav',
#  'tra_048_6_ov1_s1_01.wav',
#  'tra_119_9_ov1_s1_03.wav',
#  'tra_063_11_ov1_s1_00.wav',
#  'tra_163_15_ov1_s1_04.wav',
#  'tra_076_13_ov1_s1_04.wav',
#  'tra_172_10_ov1_s1_08.wav',
#  'tra_076_3_ov1_s1_08.wav',
#  'tra_155_5_ov1_s1_08.wav',
#  'tra_081_8_ov1_s1_10.wav',
#  'tra_144_5_ov1_s1_09.wav',
#  'tra_189_14_ov1_s1_02.wav',
#  'tra_135_4_ov1_s1_03.wav',
#  'tra_003_6_ov1_s1_00.wav',
#  'tra_045_14_ov1_s1_03.wav',
#  'tra_139_15_ov1_s1_05.wav',
#  'tra_167_13_ov1_s1_08.wav',
#  'tra_228_3_ov1_s1_00.wav',
#  'tra_008_2_ov1_s1_04.wav',
#  'tra_090_0_ov1_s1_03.wav',
#  'tra_171_0_ov1_s1_00.wav',
#  'tra_231_7_ov1_s1_01.wav',
#  'tra_237_3_ov1_s1_02.wav',
#  'tra_176_3_ov1_s1_06.wav',
#  'tra_075_0_ov1_s1_02.wav',
#  'tra_025_17_ov1_s1_01.wav',
#  'tra_139_14_ov1_s1_01.wav',
#  'tra_172_1_ov1_s1_07.wav',
#  'tra_169_10_ov1_s1_07.wav',
#  'tra_169_2_ov1_s1_03.wav',
#  'tra_185_12_ov1_s1_06.wav',
#  'tra_189_10_ov1_s1_00.wav',
#  'tra_185_3_ov1_s1_04.wav',
#  'tra_174_11_ov1_s1_09.wav',
#  'tra_140_12_ov1_s1_04.wav',
#  'tra_165_11_ov1_s1_06.wav',
#  'tra_150_7_ov1_s1_01.wav',
#  'tra_033_0_ov1_s1_03.wav',
#  'tra_221_9_ov1_s1_05.wav',
#  'tra_132_7_ov1_s1_10.wav',
#  'tra_221_4_ov1_s1_02.wav',
#  'tra_006_3_ov1_s1_04.wav',
#  'tra_056_0_ov1_s1_08.wav',
#  'tra_103_2_ov1_s1_10.wav',
#  'tra_061_10_ov1_s1_10.wav',
#  'tra_008_14_ov1_s1_02.wav',
#  'tra_102_1_ov1_s1_08.wav',
#  'tra_061_2_ov1_s1_05.wav',
#  'tra_172_0_ov1_s1_02.wav',
#  'tra_196_12_ov1_s1_01.wav',
#  'tra_132_10_ov1_s1_00.wav',
#  'tra_045_10_ov1_s1_03.wav',
#  'tra_119_5_ov1_s1_09.wav',
#  'tra_101_9_ov1_s1_09.wav',
#  'tra_005_7_ov1_s1_00.wav',
#  'tra_139_16_ov1_s1_10.wav',
#  'tra_125_14_ov1_s1_06.wav',
#  'tra_196_9_ov1_s1_10.wav',
#  'tra_025_3_ov1_s1_08.wav',
#  'tra_007_12_ov1_s1_04.wav',
#  'tra_079_11_ov1_s1_04.wav',
#  'tra_199_8_ov1_s1_03.wav',
#  'tra_119_2_ov1_s1_08.wav',
#  'tra_063_10_ov1_s1_10.wav',
#  'tra_143_7_ov1_s1_01.wav',
#  'tra_054_13_ov1_s1_02.wav',
#  'tra_119_0_ov1_s1_05.wav',
#  'tra_187_15_ov1_s1_09.wav',
#  'tra_132_3_ov1_s1_08.wav',
#  'tra_157_11_ov1_s1_02.wav',
#  'tra_139_12_ov1_s1_01.wav',
#  'tra_002_9_ov1_s1_00.wav',
#  'tra_143_3_ov1_s1_06.wav',
#  'tra_154_7_ov1_s1_00.wav',
#  'tra_202_1_ov1_s1_00.wav',
#  'tra_140_3_ov1_s1_03.wav',
#  'tra_048_1_ov1_s1_03.wav',
#  'tra_132_14_ov1_s1_01.wav',
#  'tra_146_5_ov1_s1_03.wav',
#  'tra_141_0_ov1_s1_03.wav',
#  'tra_094_10_ov1_s1_02.wav',
#  'tra_071_10_ov1_s1_10.wav',
#  'tra_049_6_ov1_s1_08.wav',
#  'tra_224_3_ov1_s1_03.wav',
#  'tra_061_6_ov1_s1_06.wav',
#  'tra_063_5_ov1_s1_07.wav',
#  'tra_082_13_ov1_s1_04.wav',
#  'tra_033_1_ov1_s1_03.wav',
#  'tra_010_2_ov1_s1_02.wav',
#  'tra_071_5_ov1_s1_09.wav',
#  'tra_227_6_ov1_s1_04.wav',
#  'tra_099_5_ov1_s1_00.wav',
#  'tra_040_15_ov1_s1_06.wav',
#  'tra_196_8_ov1_s1_01.wav',
#  'tra_010_11_ov1_s1_06.wav',
#  'tra_059_10_ov1_s1_02.wav',
#  'tra_231_3_ov1_s1_04.wav',
#  'tra_094_2_ov1_s1_03.wav',
#  'tra_171_9_ov1_s1_03.wav',
#  'tra_090_6_ov1_s1_09.wav',
#  'tra_073_10_ov1_s1_06.wav',
#  'tra_224_7_ov1_s1_07.wav',
#  'tra_034_12_ov1_s1_08.wav',
#  'tra_039_10_ov1_s1_10.wav',
#  'tra_140_13_ov1_s1_09.wav',
#  'tra_238_4_ov1_s1_04.wav',
#  'tra_171_10_ov1_s1_08.wav',
#  'tra_033_9_ov1_s1_03.wav',
#  'tra_196_1_ov1_s1_06.wav',
#  'tra_006_14_ov1_s1_04.wav',
#  'tra_228_12_ov1_s1_04.wav',
#  'tra_049_10_ov1_s1_00.wav',
#  'tra_172_8_ov1_s1_05.wav',
#  'tra_238_12_ov1_s1_04.wav',
#  'tra_006_7_ov1_s1_07.wav',
#  'tra_230_13_ov1_s1_01.wav',
#  'tra_224_12_ov1_s1_06.wav',
#  'tra_166_12_ov1_s1_05.wav',
#  'tra_150_11_ov1_s1_08.wav',
#  'tra_227_7_ov1_s1_07.wav',
#  'tra_187_16_ov1_s1_02.wav',
#  'tra_036_10_ov1_s1_09.wav',
#  'tra_000_15_ov1_s1_02.wav',
#  'tra_206_9_ov1_s1_09.wav',
#  'tra_231_4_ov1_s1_08.wav',
#  'tra_221_11_ov1_s1_06.wav',
#  'tra_000_12_ov1_s1_00.wav',
#  'tra_143_11_ov1_s1_07.wav',
#  'tra_216_9_ov1_s1_10.wav',
#  'tra_006_15_ov1_s1_06.wav',
#  'tra_005_2_ov1_s1_10.wav',
#  'tra_045_6_ov1_s1_01.wav',
#  'tra_039_9_ov1_s1_03.wav',
#  'tra_221_6_ov1_s1_02.wav',
#  'tra_040_13_ov1_s1_02.wav',
#  'tra_185_4_ov1_s1_00.wav',
#  'tra_050_13_ov1_s1_05.wav',
#  'tra_225_7_ov1_s1_00.wav',
#  'tra_165_4_ov1_s1_02.wav',
#  'tra_104_1_ov1_s1_00.wav',
#  'tra_094_7_ov1_s1_05.wav',
#  'tra_117_8_ov1_s1_09.wav',
#  'tra_163_10_ov1_s1_06.wav',
#  'tra_081_13_ov1_s1_02.wav',
#  'tra_050_10_ov1_s1_06.wav',
#  'tra_049_14_ov1_s1_04.wav',
#  'tra_098_3_ov1_s1_09.wav',
#  'tra_049_11_ov1_s1_08.wav',
#  'tra_004_5_ov1_s1_07.wav',
#  'tra_104_7_ov1_s1_05.wav',
#  'tra_137_14_ov1_s1_01.wav',
#  'tra_216_16_ov1_s1_09.wav',
#  'tra_049_4_ov1_s1_02.wav',
#  'tra_150_4_ov1_s1_00.wav',
#  'tra_212_11_ov1_s1_09.wav',
#  'tra_087_5_ov1_s1_09.wav',
#  'tra_025_0_ov1_s1_10.wav',
#  'tra_020_7_ov1_s1_07.wav',
#  'tra_220_1_ov1_s1_04.wav',
#  'tra_161_9_ov1_s1_04.wav',
#  'tra_132_2_ov1_s1_04.wav',
#  'tra_166_10_ov1_s1_03.wav',
#  'tra_172_11_ov1_s1_00.wav',
#  'tra_076_9_ov1_s1_08.wav',
#  'tra_187_4_ov1_s1_07.wav',
#  'tra_029_2_ov1_s1_06.wav',
#  'tra_090_7_ov1_s1_04.wav',
#  'tra_059_14_ov1_s1_02.wav',
#  'tra_171_3_ov1_s1_01.wav',
#  'tra_007_13_ov1_s1_04.wav',
#  'tra_040_1_ov1_s1_07.wav',
#  'tra_094_0_ov1_s1_06.wav',
#  'tra_042_5_ov1_s1_00.wav',
#  'tra_073_0_ov1_s1_07.wav',
#  'tra_159_8_ov1_s1_04.wav',
#  'tra_166_6_ov1_s1_06.wav',
#  'tra_040_2_ov1_s1_07.wav',
#  'tra_179_1_ov1_s1_04.wav',
#  'tra_230_10_ov1_s1_07.wav',
#  'tra_004_11_ov1_s1_06.wav',
#  'tra_202_3_ov1_s1_05.wav',
#  'tra_168_13_ov1_s1_08.wav',
#  'tra_157_7_ov1_s1_06.wav',
#  'tra_135_1_ov1_s1_00.wav',
#  'tra_137_12_ov1_s1_09.wav',
#  'tra_168_2_ov1_s1_06.wav',
#  'tra_018_2_ov1_s1_04.wav',
#  'tra_066_6_ov1_s1_09.wav',
#  'tra_196_2_ov1_s1_01.wav',
#  'tra_169_7_ov1_s1_05.wav',
#  'tra_125_5_ov1_s1_07.wav',
#  'tra_189_9_ov1_s1_06.wav',
#  'tra_154_5_ov1_s1_01.wav',
#  'tra_029_8_ov1_s1_08.wav',
#  'tra_203_2_ov1_s1_09.wav',
#  'tra_087_9_ov1_s1_04.wav',
#  'tra_074_10_ov1_s1_04.wav',
#  'tra_050_1_ov1_s1_07.wav',
#  'tra_119_11_ov1_s1_03.wav',
#  'tra_000_14_ov1_s1_02.wav',
#  'tra_165_3_ov1_s1_07.wav',
#  'tra_155_6_ov1_s1_04.wav',
#  'tra_008_12_ov1_s1_09.wav',
#  'tra_174_3_ov1_s1_09.wav',
#  'tra_081_14_ov1_s1_10.wav',
#  'tra_008_7_ov1_s1_10.wav',
#  'tra_000_11_ov1_s1_07.wav',
#  'tra_054_10_ov1_s1_05.wav',
#  'tra_155_7_ov1_s1_00.wav',
#  'tra_099_8_ov1_s1_08.wav',
#  'tra_166_9_ov1_s1_03.wav',
#  'tra_139_1_ov1_s1_09.wav',
#  'tra_225_5_ov1_s1_01.wav',
#  'tra_006_10_ov1_s1_00.wav',
#  'tra_102_5_ov1_s1_00.wav',
#  'tra_005_10_ov1_s1_05.wav',
#  'tra_048_9_ov1_s1_02.wav',
#  'tra_228_7_ov1_s1_06.wav',
#  'tra_099_0_ov1_s1_03.wav',
#  'tra_090_2_ov1_s1_09.wav',
#  'tra_026_4_ov1_s1_04.wav',
#  'tra_054_0_ov1_s1_01.wav',
#  'tra_123_2_ov1_s1_09.wav',
#  'tra_195_3_ov1_s1_09.wav',
#  'tra_069_4_ov1_s1_04.wav',
#  'tra_073_2_ov1_s1_02.wav',
#  'tra_230_3_ov1_s1_07.wav',
#  'tra_167_3_ov1_s1_00.wav',
#  'tra_075_6_ov1_s1_00.wav',
#  'tra_004_12_ov1_s1_08.wav',
#  'tra_140_14_ov1_s1_03.wav',
#  'tra_104_2_ov1_s1_01.wav',
#  'tra_168_12_ov1_s1_00.wav',
#  'tra_048_8_ov1_s1_05.wav',
#  'tra_076_15_ov1_s1_04.wav',
#  'tra_224_4_ov1_s1_01.wav',
#  'tra_003_9_ov1_s1_03.wav',
#  'tra_105_1_ov1_s1_09.wav',
#  'tra_139_4_ov1_s1_07.wav',
#  'tra_216_8_ov1_s1_02.wav',
#  'tra_054_4_ov1_s1_01.wav',
#  'tra_171_2_ov1_s1_02.wav',
#  'tra_059_4_ov1_s1_08.wav',
#  'tra_003_10_ov1_s1_06.wav',
#  'tra_054_11_ov1_s1_09.wav',
#  'tra_224_9_ov1_s1_06.wav',
#  'tra_003_1_ov1_s1_03.wav',
#  'tra_171_13_ov1_s1_01.wav',
#  'tra_135_11_ov1_s1_06.wav',
#  'tra_010_12_ov1_s1_04.wav',
#  'tra_039_2_ov1_s1_00.wav',
#  'tra_059_1_ov1_s1_09.wav',
#  'tra_154_8_ov1_s1_00.wav',
#  'tra_155_2_ov1_s1_07.wav',
#  'tra_199_2_ov1_s1_08.wav',
#  'tra_226_3_ov1_s1_09.wav',
#  'tra_182_1_ov1_s1_00.wav',
#  'tra_224_1_ov1_s1_04.wav',
#  'tra_008_6_ov1_s1_07.wav',
#  'tra_199_3_ov1_s1_00.wav',
#  'tra_079_10_ov1_s1_06.wav',
#  'tra_020_12_ov1_s1_04.wav',
#  'tra_140_9_ov1_s1_02.wav',
#  'tra_104_11_ov1_s1_08.wav',
#  'tra_163_1_ov1_s1_09.wav',
#  'tra_146_2_ov1_s1_00.wav',
#  'tra_165_1_ov1_s1_04.wav',
#  'tra_202_4_ov1_s1_00.wav',
#  'tra_239_10_ov1_s1_06.wav',
#  'tra_169_3_ov1_s1_08.wav',
#  'tra_101_12_ov1_s1_08.wav',
#  'tra_004_10_ov1_s1_08.wav',
#  'tra_189_5_ov1_s1_01.wav',
#  'tra_163_13_ov1_s1_06.wav',
#  'tra_198_2_ov1_s1_10.wav',
#  'tra_066_8_ov1_s1_04.wav',
#  'tra_029_12_ov1_s1_04.wav',
#  'tra_137_8_ov1_s1_08.wav',
#  'tra_049_13_ov1_s1_06.wav',
#  'tra_198_1_ov1_s1_01.wav',
#  'tra_050_2_ov1_s1_08.wav',
#  'tra_216_1_ov1_s1_04.wav',
#  'tra_054_6_ov1_s1_09.wav',
#  'tra_099_11_ov1_s1_08.wav',
#  'tra_025_11_ov1_s1_02.wav',
#  'tra_157_9_ov1_s1_07.wav',
#  'tra_040_5_ov1_s1_08.wav',
#  'tra_132_0_ov1_s1_09.wav',
#  'tra_039_12_ov1_s1_03.wav',
#  'tra_132_9_ov1_s1_08.wav',
#  'tra_090_11_ov1_s1_09.wav',
#  'tra_048_3_ov1_s1_10.wav',
#  'tra_047_3_ov1_s1_08.wav',
#  'tra_156_10_ov1_s1_01.wav',
#  'tra_137_4_ov1_s1_02.wav',
#  'tra_089_13_ov1_s1_02.wav',
#  'tra_009_6_ov1_s1_09.wav',
#  'tra_008_1_ov1_s1_08.wav',
#  'tra_003_4_ov1_s1_09.wav',
#  'tra_091_5_ov1_s1_07.wav',
#  'tra_061_3_ov1_s1_01.wav',
#  'tra_216_4_ov1_s1_05.wav',
#  'tra_006_1_ov1_s1_01.wav',
#  'tra_010_1_ov1_s1_03.wav',
#  'tra_116_9_ov1_s1_02.wav',
#  'tra_163_0_ov1_s1_07.wav',
#  'tra_166_7_ov1_s1_08.wav',
#  'tra_048_7_ov1_s1_00.wav',
#  'tra_066_13_ov1_s1_09.wav',
#  'tra_063_8_ov1_s1_07.wav',
#  'tra_169_6_ov1_s1_10.wav',
#  'tra_125_4_ov1_s1_05.wav',
#  'tra_181_13_ov1_s1_04.wav',
#  'tra_168_9_ov1_s1_02.wav',
#  'tra_155_1_ov1_s1_10.wav',
#  'tra_141_9_ov1_s1_04.wav',
#  'tra_157_0_ov1_s1_10.wav',
#  'tra_166_8_ov1_s1_04.wav',
#  'tra_108_13_ov1_s1_03.wav',
#  'tra_187_10_ov1_s1_09.wav',
#  'tra_018_1_ov1_s1_04.wav',
#  'tra_199_5_ov1_s1_07.wav',
#  'tra_227_10_ov1_s1_10.wav',
#  'tra_187_2_ov1_s1_01.wav',
#  'tra_067_5_ov1_s1_03.wav',
#  'tra_125_0_ov1_s1_09.wav',
#  'tra_168_4_ov1_s1_02.wav',
#  'tra_158_0_ov1_s1_04.wav',
#  'tra_000_1_ov1_s1_04.wav',
#  'tra_009_8_ov1_s1_07.wav',
#  'tra_031_7_ov1_s1_08.wav',
#  'tra_150_0_ov1_s1_06.wav',
#  'tra_026_13_ov1_s1_02.wav',
#  'tra_054_14_ov1_s1_06.wav',
#  'tra_100_5_ov1_s1_00.wav',
#  'tra_171_8_ov1_s1_07.wav',
#  'tra_185_7_ov1_s1_01.wav',
#  'tra_185_9_ov1_s1_08.wav',
#  'tra_211_6_ov1_s1_07.wav',
#  'tra_182_6_ov1_s1_06.wav',
#  'tra_228_6_ov1_s1_08.wav',
#  'tra_180_0_ov1_s1_04.wav',
#  'tra_184_7_ov1_s1_04.wav',
#  'tra_091_12_ov1_s1_10.wav',
#  'tra_000_2_ov1_s1_06.wav',
#  'tra_176_9_ov1_s1_04.wav',
#  'tra_002_12_ov1_s1_04.wav',
#  'tra_104_9_ov1_s1_03.wav',
#  'tra_218_5_ov1_s1_06.wav',
#  'tra_139_8_ov1_s1_09.wav',
#  'tra_171_14_ov1_s1_06.wav',
#  'tra_028_3_ov1_s1_04.wav',
#  'tra_094_5_ov1_s1_02.wav',
#  'tra_187_1_ov1_s1_02.wav',
#  'tra_140_7_ov1_s1_04.wav',
#  'tra_199_15_ov1_s1_06.wav',
#  'tra_198_7_ov1_s1_02.wav',
#  'tra_061_8_ov1_s1_09.wav',
#  'tra_039_6_ov1_s1_04.wav',
#  'tra_218_10_ov1_s1_09.wav',
#  'tra_119_4_ov1_s1_05.wav',
#  'tra_091_6_ov1_s1_04.wav',
#  'tra_116_12_ov1_s1_07.wav',
#  'tra_029_10_ov1_s1_09.wav',
#  'tra_116_13_ov1_s1_05.wav',
#  'tra_094_9_ov1_s1_01.wav',
#  'tra_009_9_ov1_s1_05.wav',
#  'tra_010_7_ov1_s1_06.wav',
#  'tra_172_3_ov1_s1_08.wav',
#  'tra_150_8_ov1_s1_01.wav',
#  'tra_038_11_ov1_s1_09.wav',
#  'tra_102_2_ov1_s1_00.wav',
#  'tra_236_10_ov1_s1_04.wav',
#  'tra_009_3_ov1_s1_08.wav',
#  'tra_163_9_ov1_s1_06.wav',
#  'tra_090_9_ov1_s1_09.wav',
#  'tra_042_10_ov1_s1_04.wav',
#  'tra_180_9_ov1_s1_04.wav',
#  'tra_026_12_ov1_s1_03.wav',
#  'tra_039_0_ov1_s1_03.wav',
#  'tra_166_14_ov1_s1_06.wav',
#  'tra_172_7_ov1_s1_02.wav',
#  'tra_155_11_ov1_s1_10.wav',
#  'tra_024_6_ov1_s1_07.wav',
#  'tra_039_4_ov1_s1_08.wav',
#  'tra_009_5_ov1_s1_02.wav',
#  'tra_071_8_ov1_s1_10.wav',
#  'tra_187_9_ov1_s1_10.wav',
#  'tra_101_8_ov1_s1_04.wav',
#  'tra_196_6_ov1_s1_04.wav',
#  'tra_150_6_ov1_s1_05.wav',
#  'tra_102_4_ov1_s1_03.wav',
#  'tra_116_6_ov1_s1_00.wav',
#  'tra_090_4_ov1_s1_02.wav',
#  'tra_218_8_ov1_s1_04.wav',
#  'tra_006_13_ov1_s1_07.wav',
#  'tra_009_13_ov1_s1_08.wav',
#  'tra_116_10_ov1_s1_06.wav',
#  'tra_076_6_ov1_s1_07.wav',
#  'tra_054_1_ov1_s1_04.wav',
#  'tra_050_4_ov1_s1_00.wav',
#  'tra_073_13_ov1_s1_04.wav',
#  'tra_163_4_ov1_s1_04.wav',
#  'tra_227_12_ov1_s1_04.wav',
#  'tra_028_0_ov1_s1_07.wav',
#  'tra_177_9_ov1_s1_02.wav',
#  'tra_017_8_ov1_s1_06.wav',
#  'tra_101_10_ov1_s1_07.wav',
#  'tra_145_4_ov1_s1_09.wav',
#  'tra_026_5_ov1_s1_03.wav',
#  'tra_054_15_ov1_s1_01.wav',
#  'tra_092_9_ov1_s1_02.wav',
#  'tra_182_12_ov1_s1_02.wav',
#  'tra_119_1_ov1_s1_03.wav',
#  'tra_100_3_ov1_s1_08.wav',
#  'tra_167_12_ov1_s1_06.wav',
#  'tra_218_4_ov1_s1_01.wav',
#  'tra_029_1_ov1_s1_08.wav',
#  'tra_221_8_ov1_s1_03.wav',
#  'tra_166_2_ov1_s1_09.wav',
#  'tra_146_6_ov1_s1_08.wav',
#  'tra_026_11_ov1_s1_00.wav',
#  'tra_028_7_ov1_s1_07.wav',
#  'tra_167_2_ov1_s1_00.wav',
#  'tra_101_1_ov1_s1_08.wav',
#  'tra_108_5_ov1_s1_04.wav',
#  'tra_236_11_ov1_s1_01.wav',
#  'tra_203_10_ov1_s1_02.wav',
#  'tra_040_9_ov1_s1_09.wav',
#  'tra_009_14_ov1_s1_03.wav',
#  'tra_081_6_ov1_s1_08.wav',
#  'tra_000_4_ov1_s1_01.wav',
#  'tra_079_9_ov1_s1_01.wav',
#  'tra_191_8_ov1_s1_04.wav',
#  'tra_059_11_ov1_s1_02.wav',
#  'tra_229_10_ov1_s1_07.wav',
#  'tra_071_2_ov1_s1_08.wav',
#  'tra_171_12_ov1_s1_07.wav',
#  'tra_135_9_ov1_s1_03.wav',
#  'tra_216_0_ov1_s1_08.wav',
#  'tra_171_11_ov1_s1_06.wav',
#  'tra_125_8_ov1_s1_01.wav',
#  'tra_094_13_ov1_s1_08.wav',
#  'tra_189_4_ov1_s1_02.wav',
#  'tra_004_9_ov1_s1_07.wav',
#  'tra_116_2_ov1_s1_01.wav',
#  'tra_132_15_ov1_s1_05.wav',
#  'tra_025_13_ov1_s1_02.wav',
#  'tra_091_13_ov1_s1_05.wav',
#  'tra_228_1_ov1_s1_02.wav',
#  'tra_130_7_ov1_s1_09.wav',
#  'tra_061_5_ov1_s1_06.wav',
#  'tra_000_6_ov1_s1_09.wav',
#  'tra_116_4_ov1_s1_10.wav',
#  'tra_181_0_ov1_s1_09.wav',
#  'tra_132_12_ov1_s1_02.wav',
#  'tra_090_8_ov1_s1_00.wav',
#  'tra_024_10_ov1_s1_10.wav',
#  'tra_004_3_ov1_s1_03.wav',
#  'tra_185_13_ov1_s1_04.wav',
#  'tra_059_15_ov1_s1_10.wav',
#  'tra_067_4_ov1_s1_09.wav',
#  'tra_000_8_ov1_s1_07.wav',
#  'tra_137_2_ov1_s1_08.wav',
#  'tra_135_13_ov1_s1_07.wav',
#  'tra_140_5_ov1_s1_03.wav',
#  'tra_172_2_ov1_s1_00.wav',
#  'tra_224_2_ov1_s1_03.wav',
#  'tra_085_7_ov1_s1_04.wav',
#  'tra_229_0_ov1_s1_05.wav',
#  'tra_168_7_ov1_s1_02.wav',
#  'tra_116_5_ov1_s1_04.wav',
#  'tra_140_8_ov1_s1_01.wav',
#  'tra_150_3_ov1_s1_06.wav',
#  'tra_017_9_ov1_s1_02.wav',
#  'tra_050_5_ov1_s1_06.wav',
#  'tra_081_2_ov1_s1_00.wav',
#  'tra_154_4_ov1_s1_06.wav',
#  'tra_015_13_ov1_s1_04.wav',
#  'tra_024_7_ov1_s1_06.wav',
#  'tra_182_4_ov1_s1_06.wav',
#  'tra_199_14_ov1_s1_04.wav',
#  'tra_043_11_ov1_s1_04.wav',
#  'tra_104_6_ov1_s1_05.wav',
#  'tra_067_2_ov1_s1_07.wav',
#  'tra_042_15_ov1_s1_00.wav',
#  'tra_199_0_ov1_s1_03.wav',
#  'tra_167_14_ov1_s1_00.wav',
#  'tra_082_2_ov1_s1_09.wav',
#  'tra_228_10_ov1_s1_10.wav',
#  'tra_187_12_ov1_s1_07.wav',
#  'tra_141_4_ov1_s1_04.wav',
#  'tra_090_13_ov1_s1_08.wav',
#  'tra_192_12_ov1_s1_04.wav',
#  'tra_158_8_ov1_s1_04.wav',
#  'tra_008_0_ov1_s1_05.wav',
#  'tra_048_5_ov1_s1_10.wav',
#  'tra_155_4_ov1_s1_05.wav',
#  'tra_154_9_ov1_s1_03.wav',
#  'tra_075_10_ov1_s1_01.wav',
#  'tra_110_2_ov1_s1_04.wav',
#  'tra_119_3_ov1_s1_07.wav',
#  'tra_176_10_ov1_s1_04.wav',
#  'tra_061_12_ov1_s1_08.wav',
#  'tra_139_2_ov1_s1_00.wav',
#  'tra_079_4_ov1_s1_06.wav',
#  'tra_171_7_ov1_s1_09.wav',
#  'tra_143_0_ov1_s1_09.wav',
#  'tra_081_0_ov1_s1_00.wav',
#  'tra_067_6_ov1_s1_06.wav',
#  'tra_005_12_ov1_s1_04.wav',
#  'tra_025_7_ov1_s1_04.wav',
#  'tra_203_1_ov1_s1_04.wav',
#  'tra_139_7_ov1_s1_06.wav',
#  'tra_005_11_ov1_s1_08.wav',
#  'tra_017_1_ov1_s1_01.wav',
#  'tra_076_12_ov1_s1_02.wav',
#  'tra_108_12_ov1_s1_03.wav',
#  'tra_139_10_ov1_s1_08.wav',
#  'tra_101_11_ov1_s1_03.wav',
#  'tra_003_3_ov1_s1_09.wav',
#  'tra_155_9_ov1_s1_08.wav',
#  'tra_026_8_ov1_s1_00.wav',
#  'tra_130_6_ov1_s1_04.wav',
#  'tra_135_6_ov1_s1_07.wav',
#  'tra_026_10_ov1_s1_06.wav',
#  'tra_029_13_ov1_s1_06.wav',
#  'tra_140_10_ov1_s1_03.wav',
#  'tra_157_5_ov1_s1_10.wav',
#  'tra_054_2_ov1_s1_01.wav',
#  'tra_168_14_ov1_s1_07.wav',
#  'tra_004_13_ov1_s1_09.wav',
#  'tra_073_4_ov1_s1_07.wav',
#  'tra_125_1_ov1_s1_04.wav',
#  'tra_025_15_ov1_s1_08.wav',
#  'tra_101_0_ov1_s1_10.wav',
#  'tra_104_5_ov1_s1_10.wav',
#  'tra_228_0_ov1_s1_09.wav',
#  'tra_200_3_ov1_s1_07.wav',
#  'tra_155_13_ov1_s1_08.wav',
#  'tra_049_3_ov1_s1_08.wav',
#  'tra_137_16_ov1_s1_02.wav',
#  'tra_224_5_ov1_s1_10.wav',
#  'tra_108_0_ov1_s1_05.wav',
#  'tra_025_5_ov1_s1_10.wav',
#  'tra_239_1_ov1_s1_04.wav',
#  'tra_185_0_ov1_s1_10.wav',
#  'tra_028_11_ov1_s1_10.wav',
#  'tra_203_9_ov1_s1_08.wav',
#  'tra_090_1_ov1_s1_10.wav',
#  'tra_181_5_ov1_s1_10.wav',
#  'tra_076_4_ov1_s1_04.wav',
#  'tra_071_9_ov1_s1_01.wav',
#  'tra_161_4_ov1_s1_04.wav',
#  'tra_140_1_ov1_s1_03.wav',
#  'tra_195_1_ov1_s1_09.wav',
#  'tra_127_2_ov1_s1_02.wav',
#  'tra_097_1_ov1_s1_05.wav',
#  'tra_231_13_ov1_s1_05.wav',
#  'tra_165_14_ov1_s1_02.wav',
#  'tra_097_0_ov1_s1_09.wav',
#  'tra_017_13_ov1_s1_05.wav',
#  'tra_119_8_ov1_s1_09.wav',
#  'tra_025_6_ov1_s1_04.wav',
#  'tra_049_5_ov1_s1_10.wav',
#  'tra_221_1_ov1_s1_06.wav',
#  'tra_075_12_ov1_s1_06.wav',
#  'tra_061_4_ov1_s1_01.wav',
#  'tra_185_5_ov1_s1_02.wav',
#  'tra_005_5_ov1_s1_10.wav',
#  'tra_048_13_ov1_s1_02.wav',
#  'tra_163_2_ov1_s1_03.wav',
#  'tra_008_4_ov1_s1_08.wav',
#  'tra_227_3_ov1_s1_06.wav',
#  'tra_203_12_ov1_s1_06.wav',
#  'tra_125_2_ov1_s1_01.wav',
#  'tra_024_4_ov1_s1_03.wav',
#  'tra_194_11_ov1_s1_04.wav',
#  'tra_067_10_ov1_s1_07.wav',
#  'tra_167_4_ov1_s1_01.wav',
#  'tra_010_6_ov1_s1_02.wav',
#  'tra_157_1_ov1_s1_07.wav',
#  'tra_164_10_ov1_s1_09.wav',
#  'tra_061_1_ov1_s1_01.wav',
#  'tra_154_13_ov1_s1_04.wav',
#  'tra_199_6_ov1_s1_05.wav',
#  'tra_075_2_ov1_s1_02.wav',
#  'tra_099_2_ov1_s1_07.wav',
#  'tra_094_12_ov1_s1_05.wav',
#  'tra_218_12_ov1_s1_01.wav',
#  'tra_143_8_ov1_s1_08.wav',
#  'tra_059_8_ov1_s1_04.wav',
#  'tra_076_1_ov1_s1_03.wav',
#  'tra_230_9_ov1_s1_02.wav',
#  'tra_166_13_ov1_s1_03.wav',
#  'tra_073_1_ov1_s1_07.wav',
#  'tra_079_13_ov1_s1_04.wav',
#  'tra_140_6_ov1_s1_03.wav',
#  'tra_166_4_ov1_s1_04.wav',
#  'tra_165_12_ov1_s1_06.wav',
#  'tra_137_11_ov1_s1_09.wav',
#  'tra_132_13_ov1_s1_07.wav',
#  'tra_231_14_ov1_s1_04.wav',
#  'tra_199_13_ov1_s1_08.wav',
#  'tra_094_6_ov1_s1_03.wav',
#  'tra_068_3_ov1_s1_04.wav',
#  'tra_182_10_ov1_s1_00.wav',
#  'tra_135_3_ov1_s1_07.wav',
#  'tra_088_10_ov1_s1_04.wav',
#  'tra_063_2_ov1_s1_03.wav',
#  'tra_081_15_ov1_s1_07.wav',
#  'tra_070_5_ov1_s1_04.wav',
#  'tra_091_0_ov1_s1_05.wav',
#  'tra_155_3_ov1_s1_02.wav',
#  'tra_176_2_ov1_s1_00.wav',
#  'tra_061_11_ov1_s1_10.wav',
#  'tra_073_6_ov1_s1_00.wav',
#  'tra_078_11_ov1_s1_02.wav',
#  'tra_120_13_ov1_s1_04.wav',
#  'tra_218_1_ov1_s1_05.wav',
#  'tra_125_11_ov1_s1_03.wav',
#  'tra_203_7_ov1_s1_01.wav',
#  'tra_203_6_ov1_s1_06.wav',
#  'tra_033_8_ov1_s1_01.wav',
#  'tra_230_1_ov1_s1_08.wav',
#  'tra_231_10_ov1_s1_01.wav',
#  'tra_177_13_ov1_s1_04.wav',
#  'tra_040_10_ov1_s1_03.wav',
#  'tra_156_6_ov1_s1_06.wav',
#  'tra_054_3_ov1_s1_03.wav',
#  'tra_166_11_ov1_s1_03.wav',
#  'tra_073_5_ov1_s1_01.wav',
#  'tra_008_13_ov1_s1_03.wav',
#  'tra_039_5_ov1_s1_00.wav',
#  'tra_192_11_ov1_s1_04.wav',
#  'tra_040_4_ov1_s1_09.wav',
#  'tra_239_7_ov1_s1_04.wav',
#  'tra_063_7_ov1_s1_02.wav',
#  'tra_163_3_ov1_s1_10.wav',
#  'tra_097_11_ov1_s1_07.wav',
#  'tra_163_11_ov1_s1_10.wav',
#  'tra_029_0_ov1_s1_05.wav',
#  'tra_006_11_ov1_s1_07.wav',
#  'tra_081_7_ov1_s1_09.wav',
#  'tra_035_1_ov1_s1_04.wav',
#  'tra_165_10_ov1_s1_07.wav',
#  'tra_116_8_ov1_s1_06.wav',
#  'tra_150_1_ov1_s1_08.wav',
#  'tra_227_5_ov1_s1_00.wav',
#  'tra_026_9_ov1_s1_06.wav',
#  'tra_182_2_ov1_s1_02.wav',
#  'tra_028_9_ov1_s1_06.wav',
#  'tra_048_10_ov1_s1_09.wav',
#  'tra_199_1_ov1_s1_09.wav',
#  'tra_049_9_ov1_s1_07.wav',
#  'tra_143_1_ov1_s1_07.wav',
#  'tra_167_10_ov1_s1_00.wav',
#  'tra_059_5_ov1_s1_01.wav',
#  'tra_114_8_ov1_s1_00.wav',
#  'tra_216_6_ov1_s1_07.wav',
#  'tra_102_15_ov1_s1_02.wav',
#  'tra_004_7_ov1_s1_02.wav',
#  'tra_202_9_ov1_s1_05.wav',
#  'tra_017_10_ov1_s1_09.wav',
#  'tra_057_1_ov1_s1_04.wav',
#  'tra_017_6_ov1_s1_07.wav',
#  'tra_009_1_ov1_s1_03.wav',
#  'tra_073_12_ov1_s1_10.wav',
#  'tra_203_5_ov1_s1_03.wav',
#  'tra_102_13_ov1_s1_00.wav',
#  'tra_229_3_ov1_s1_08.wav',
#  'tra_163_6_ov1_s1_01.wav',
#  'tra_154_11_ov1_s1_02.wav',
#  'tra_231_12_ov1_s1_03.wav',
#  'tra_017_5_ov1_s1_10.wav',
#  'tra_045_3_ov1_s1_00.wav',
#  'tra_101_2_ov1_s1_05.wav',
#  'tra_073_9_ov1_s1_09.wav',
#  'tra_006_6_ov1_s1_03.wav',
#  'tra_044_8_ov1_s1_02.wav',
#  'tra_216_5_ov1_s1_00.wav',
#  'tra_094_8_ov1_s1_04.wav',
#  'tra_226_6_ov1_s1_08.wav',
#  'tra_102_3_ov1_s1_08.wav',
#  'tra_231_11_ov1_s1_10.wav',
#  'tra_059_0_ov1_s1_07.wav',
#  'tra_025_4_ov1_s1_09.wav',
#  'tra_007_1_ov1_s1_09.wav',
#  'tra_230_2_ov1_s1_03.wav',
#  'tra_126_0_ov1_s1_09.wav',
#  'tra_165_16_ov1_s1_00.wav',
#  'tra_147_0_ov1_s1_04.wav',
#  'tra_112_1_ov1_s1_09.wav',
#  'tra_231_9_ov1_s1_08.wav',
#  'tra_221_0_ov1_s1_07.wav',
#  'tra_072_5_ov1_s1_10.wav',
#  'tra_196_0_ov1_s1_07.wav',
#  'tra_227_11_ov1_s1_05.wav',
#  'tra_218_3_ov1_s1_09.wav',
#  'tra_073_8_ov1_s1_00.wav',
#  'tra_064_2_ov1_s1_01.wav',
#  'tra_119_10_ov1_s1_05.wav',
#  'tra_229_8_ov1_s1_03.wav',
#  'tra_090_12_ov1_s1_03.wav',
#  'tra_101_5_ov1_s1_02.wav',
#  'tra_054_9_ov1_s1_03.wav',
#  'tra_003_8_ov1_s1_02.wav',
#  'tra_076_7_ov1_s1_06.wav',
#  'tra_137_5_ov1_s1_10.wav',
#  'tra_203_0_ov1_s1_05.wav',
#  'tra_198_3_ov1_s1_10.wav',
#  'tra_170_3_ov1_s1_09.wav',
#  'tra_000_16_ov1_s1_00.wav',
#  'tra_187_7_ov1_s1_07.wav',
#  'tra_017_4_ov1_s1_04.wav',
#  'tra_165_7_ov1_s1_04.wav',
#  'tra_167_9_ov1_s1_09.wav',
#  'tra_079_7_ov1_s1_00.wav',
#  'tra_102_10_ov1_s1_10.wav',
#  'tra_221_10_ov1_s1_10.wav',
#  'tra_216_3_ov1_s1_03.wav',
#  'tra_054_5_ov1_s1_04.wav',
#  'tra_017_12_ov1_s1_03.wav',
#  'tra_025_9_ov1_s1_06.wav',
#  'tra_074_12_ov1_s1_04.wav',
#  'tra_047_4_ov1_s1_04.wav',
#  'tra_230_11_ov1_s1_06.wav',
#  'tra_154_10_ov1_s1_09.wav',
#  'tra_024_0_ov1_s1_07.wav',
#  'tra_097_6_ov1_s1_08.wav',
#  'tra_049_2_ov1_s1_09.wav',
#  'tra_202_11_ov1_s1_00.wav',
#  'tra_091_2_ov1_s1_04.wav',
#  'tra_202_13_ov1_s1_07.wav',
#  'tra_167_6_ov1_s1_03.wav',
#  'tra_153_8_ov1_s1_04.wav',
#  'tra_048_0_ov1_s1_05.wav',
#  'tra_132_8_ov1_s1_08.wav',
#  'tra_079_3_ov1_s1_10.wav',
#  'tra_167_0_ov1_s1_02.wav',
#  'tra_168_1_ov1_s1_00.wav',
#  'tra_075_9_ov1_s1_02.wav',
#  'tra_135_14_ov1_s1_08.wav',
#  'tra_009_7_ov1_s1_07.wav',
#  'tra_230_12_ov1_s1_10.wav',
#  'tra_026_2_ov1_s1_05.wav',
#  'tra_071_4_ov1_s1_02.wav',
#  'tra_180_11_ov1_s1_04.wav',
#  'tra_228_8_ov1_s1_05.wav',
#  'tra_135_12_ov1_s1_07.wav',
#  'tra_099_9_ov1_s1_00.wav',
#  'tra_075_3_ov1_s1_07.wav',
#  'tra_227_8_ov1_s1_06.wav',
#  'tra_176_4_ov1_s1_10.wav',
#  'tra_073_14_ov1_s1_09.wav',
#  'tra_219_11_ov1_s1_04.wav',
#  'tra_169_5_ov1_s1_02.wav',
#  'tra_167_1_ov1_s1_08.wav',
#  'tra_037_5_ov1_s1_02.wav',
#  'tra_169_4_ov1_s1_06.wav',
#  'tra_198_11_ov1_s1_10.wav',
#  'tra_182_8_ov1_s1_02.wav',
#  'tra_063_0_ov1_s1_03.wav',
#  'tra_182_3_ov1_s1_01.wav',
#  'tra_063_12_ov1_s1_10.wav',
#  'tra_009_2_ov1_s1_06.wav',
#  'tra_029_11_ov1_s1_04.wav',
#  'tra_010_10_ov1_s1_09.wav',
#  'tra_202_5_ov1_s1_00.wav',
#  'tra_094_1_ov1_s1_01.wav',
#  'tra_005_0_ov1_s1_10.wav',
#  'tra_048_14_ov1_s1_01.wav',
#  'tra_033_4_ov1_s1_02.wav',
#  'tra_099_4_ov1_s1_02.wav',
#  'tra_079_2_ov1_s1_02.wav',
#  'tra_203_11_ov1_s1_08.wav',
#  'tra_025_1_ov1_s1_06.wav',
#  'tra_221_2_ov1_s1_03.wav',
#  'tra_102_11_ov1_s1_01.wav',
#  'tra_091_1_ov1_s1_06.wav',
#  'tra_165_8_ov1_s1_10.wav',
#  'tra_005_3_ov1_s1_09.wav',
#  'tra_139_0_ov1_s1_03.wav',
#  'tra_185_6_ov1_s1_08.wav',
#  'tra_026_1_ov1_s1_00.wav',
#  'tra_079_0_ov1_s1_10.wav',
#  'tra_050_8_ov1_s1_07.wav',
#  'tra_033_6_ov1_s1_03.wav',
#  'tra_104_12_ov1_s1_07.wav',
#  'tra_051_14_ov1_s1_04.wav',
#  'tra_230_14_ov1_s1_10.wav',
#  'tra_146_0_ov1_s1_06.wav',
#  'tra_139_6_ov1_s1_02.wav',
#  'tra_190_3_ov1_s1_09.wav',
#  'tra_049_8_ov1_s1_00.wav',
#  'tra_169_8_ov1_s1_01.wav',
#  'tra_143_16_ov1_s1_04.wav',
#  'tra_124_6_ov1_s1_04.wav',
#  'tra_182_0_ov1_s1_01.wav',
#  'tra_009_12_ov1_s1_08.wav',
#  'tra_010_5_ov1_s1_01.wav',
#  'tra_181_9_ov1_s1_01.wav',
#  'tra_205_6_ov1_s1_07.wav',
#  'tra_024_12_ov1_s1_00.wav',
#  'tra_230_8_ov1_s1_04.wav',
#  'tra_199_12_ov1_s1_02.wav',
#  'tra_059_7_ov1_s1_04.wav',
#  'tra_150_9_ov1_s1_06.wav',
#  'tra_038_0_ov1_s1_04.wav',
#  'tra_071_12_ov1_s1_06.wav',
#  'tra_099_10_ov1_s1_10.wav',
#  'tra_141_15_ov1_s1_01.wav',
#  'tra_043_9_ov1_s1_09.wav',
#  'tra_216_7_ov1_s1_00.wav',
#  'tra_127_10_ov1_s1_04.wav',
#  'tra_050_3_ov1_s1_00.wav',
#  'tra_025_8_ov1_s1_04.wav',
#  'tra_063_4_ov1_s1_04.wav',
#  'tra_181_1_ov1_s1_05.wav',
#  'tra_137_9_ov1_s1_01.wav',
#  'tra_074_5_ov1_s1_04.wav',
#  'tra_005_15_ov1_s1_07.wav',
#  'tra_091_8_ov1_s1_02.wav',
#  'tra_155_12_ov1_s1_00.wav',
#  'tra_050_12_ov1_s1_01.wav',
#  'tra_221_3_ov1_s1_04.wav',
#  'tra_189_6_ov1_s1_09.wav',
#  'tra_053_3_ov1_s1_09.wav',
#  'tra_039_11_ov1_s1_05.wav',
#  'tra_135_7_ov1_s1_09.wav',
#  'tra_135_5_ov1_s1_03.wav',
#  'tra_029_4_ov1_s1_07.wav',
#  'tra_079_1_ov1_s1_04.wav',
#  'tra_188_13_ov1_s1_04.wav',
#  'tra_141_8_ov1_s1_05.wav',
#  'tra_156_7_ov1_s1_08.wav',
#  'tra_160_6_ov1_s1_04.wav',
#  'tra_216_11_ov1_s1_05.wav',
#  'tra_157_10_ov1_s1_05.wav',
#  'tra_176_7_ov1_s1_02.wav',
#  'tra_099_12_ov1_s1_08.wav',
#  'tra_006_0_ov1_s1_02.wav',
#  'tra_203_3_ov1_s1_04.wav',
#  'tra_182_7_ov1_s1_06.wav',
#  'tra_231_8_ov1_s1_06.wav',
#  'tra_028_10_ov1_s1_06.wav',
#  'tra_073_3_ov1_s1_01.wav',
#  'tra_143_10_ov1_s1_01.wav',
#  'tra_104_8_ov1_s1_06.wav',
#  'tra_090_3_ov1_s1_08.wav',
#  'tra_000_5_ov1_s1_00.wav',
#  'tra_227_2_ov1_s1_03.wav',
#  'tra_081_1_ov1_s1_02.wav',
#  'tra_171_4_ov1_s1_02.wav',
#  'tra_010_0_ov1_s1_06.wav',
#  'tra_141_2_ov1_s1_02.wav',
#  'tra_227_1_ov1_s1_08.wav',
#  'tra_190_2_ov1_s1_04.wav',
#  'tra_063_13_ov1_s1_05.wav',
#  'tra_181_7_ov1_s1_05.wav',
#  'tra_153_3_ov1_s1_09.wav',
#  'tra_000_3_ov1_s1_06.wav',
#  'tra_005_4_ov1_s1_06.wav',
#  'tra_108_6_ov1_s1_07.wav',
#  'tra_135_0_ov1_s1_03.wav',
#  'tra_165_9_ov1_s1_10.wav',
#  'tra_094_3_ov1_s1_02.wav',
#  ...]

# %%
audio_paths1 = '/home/cslab03/Documents/ASRColab/ASRColab/wav_separate_sounds_mono/ov1s1_wav/'
audio_paths2 = '/home/cslab03/Documents/ASRColab/ASRColab/wav_separate_sounds_mono/ov1s2_wav/'
audio_paths3 = '/home/cslab03/Documents/ASRColab/ASRColab/wav_separate_sounds_mono/ov1s3_wav/'

# %%
def load_data(X_train):
    x_train = []
    for index in range(len(X_train)):
        if "ov1_s1" in X_train[index]:
            feats = audio_paths1 + X_train[index]
        elif "ov1_s2" in X_train[index]:
            feats = audio_paths2 + X_train[index]
        elif "ov1_s3" in X_train[index]:
            feats = audio_paths3 + X_train[index]

        target = torch.tensor(int(X_train[index][-6:-4])).item()
        
        x_train.append({'paths':feats, 'labels':target})
    
    return x_train

# %%
x_train = load_data(X_train)

x_val = load_data(X_val)

x_test = load_data(X_test)

# %%
import pandas as pd

df_train = pd.DataFrame(x_train)
df_train.head()
# Out:
#                                                paths  labels
# 0  /home/cslab03/Documents/ASRColab/ASRColab/wav_...       0
# 1  /home/cslab03/Documents/ASRColab/ASRColab/wav_...       4
# 2  /home/cslab03/Documents/ASRColab/ASRColab/wav_...       9
# 3  /home/cslab03/Documents/ASRColab/ASRColab/wav_...       9
# 4  /home/cslab03/Documents/ASRColab/ASRColab/wav_...       4

# %%
print("LABELS: ", df_train['labels'].unique())

label_list = df_train['labels'].unique().tolist()
label_list.sort()
num_labels = len(label_list)

print(len(df_train['labels']))

df_train.groupby('labels').count()
# Out:
# LABELS:  [ 0  4  9  3  2  1  7  8  6  5 10]
# 2987
#         paths
# labels
# 0         250
# 1         250
# 2         280
# 3         245
# 4         418
# 5         207
# 6         266
# 7         262
# 8         257
# 9         321
# 10        231

# %%
df_val = pd.DataFrame(x_val)
df_val.head()
# Out:
#                                                paths  labels
# 0  /home/cslab03/Documents/ASRColab/ASRColab/wav_...       2
# 1  /home/cslab03/Documents/ASRColab/ASRColab/wav_...       9
# 2  /home/cslab03/Documents/ASRColab/ASRColab/wav_...       4
# 3  /home/cslab03/Documents/ASRColab/ASRColab/wav_...       0
# 4  /home/cslab03/Documents/ASRColab/ASRColab/wav_...      10

# %%
from transformers import AutoConfig, Wav2Vec2Processor

# %%
model = "facebook/wav2vec2-base-960h"

# %%
config = AutoConfig.from_pretrained(model, num_labels=num_labels, label2id = {label: i for i, label in enumerate(label_list)}, id2label = {i: label for i, label in enumerate(label_list)}, finetuning_task="wav2vec2_clf", cache_dir=None)

# %%
processor = Wav2Vec2Processor.from_pretrained(model,)

# %%
targer_sampling = processor.feature_extractor.sampling_rate
targer_sampling
# Out:
# 16000

# %%
def audio_file_to_array_fn(path):
    audio_array, sampling_rate = torchaudio.load(path)
    resampler = torchaudio.transforms.Resample(sampling_rate, targer_sampling)
    audio = resampler(audio_array).squeeze().numpy()
    return audio

def label_to_id(label):
    if len(label_list) > 0:
        return label_list.index(label) if label in label_list else -1
    return label
    
def preprocess_data(datalist):
    input_list = [audio_file_to_array_fn(input) for input in datalist['paths']]
    label_list = [label_to_id(label) for label in datalist['labels']]
    
    result = processor(input_list, sampling_rate=targer_sampling, return_tensors="pt", padding=True)
    result['labels'] = torch.tensor(label_list)
    return result

# %%
train_dataset = preprocess_data(df_train)
train_dataset
# Out:
# {'input_values': tensor([[-2.0865e-02, -7.0939e-02, -3.3383e-02,  ...,  1.6690e-03,
#           1.6690e-03,  1.6690e-03],
#         [ 1.5131e-01,  2.3052e-02, -1.2658e-01,  ...,  1.6760e-03,
#           1.6760e-03,  1.6760e-03],
#         [-6.2875e-03, -1.8330e-02, -5.4458e-02,  ..., -2.2732e-03,
#          -2.2732e-03, -2.2732e-03],
#         ...,
#         [-6.6569e-02, -3.6330e-02, -6.6569e-02,  ...,  9.0271e-03,
#           9.0271e-03,  9.0271e-03],
#         [ 3.6107e-02, -1.5254e-01, -1.7948e-01,  ...,  1.7473e-04,
#           1.7473e-04,  1.7473e-04],
#         [-6.7423e-03, -9.2959e-03,  9.1852e-04,  ...,  9.1852e-04,
#           9.1852e-04,  9.1852e-04]]), 'labels': tensor([ 0,  4,  9,  ...,  6,  7, 10])}

# %%
eval_dataset = preprocess_data(df_val)
eval_dataset
# Out:
# {'input_values': tensor([[ 0.0289, -0.0138,  0.0253,  ...,  0.0004,  0.0004,  0.0004],
#         [ 0.0186,  0.0044,  0.0398,  ...,  0.0009,  0.0009,  0.0009],
#         [ 0.0083,  0.0323,  0.0643,  ...,  0.0002,  0.0002,  0.0002],
#         ...,
#         [-0.0329,  0.0036, -0.0132,  ...,  0.0008,  0.0008,  0.0008],
#         [-0.0700, -0.0460,  0.2290,  ...,  0.0018,  0.0018,  0.0018],
#         [-0.0274, -0.0325, -0.0687,  ...,  0.0036,  0.0036,  0.0036]]), 'labels': tensor([ 2,  9,  4,  ...,  2,  4, 10])}
